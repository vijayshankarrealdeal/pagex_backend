# %%
api_key = "AIzaSyAPZBbEtPzN1PqDKtyLSdnKLIbeOZmMXF0"
cx="616ea8e78d657437c"

# %%
import requests
import json

# %%
url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&cx={cx}&q=trump"

# %%
result = requests.get(url)

# %%
res=result.json()

# %%
res['items']
# Out:
# [{'kind': 'customsearch#result',
#   'title': 'Donald Trump - Wikipedia',
#   'htmlTitle': 'Donald <b>Trump</b> - Wikipedia',
#   'link': 'https://en.wikipedia.org/wiki/Donald_Trump',
#   'displayLink': 'en.wikipedia.org',
#   'snippet': "Born in New York City, Trump graduated from the University of Pennsylvania in 1968 with a bachelor's degree in economics. He became the president of his\xa0...",
#   'htmlSnippet': 'Born in New York City, <b>Trump</b> graduated from the University of Pennsylvania in 1968 with a bachelor&#39;s degree in economics. He became the president of his&nbsp;...',
#   'formattedUrl': 'https://en.wikipedia.org/wiki/Donald_Trump',
#   'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Donald_<b>Trump</b>',
#   'pagemap': {'hcard': [{'url_text': 'White House website',
#      'bday': '1946-06-14',
#      'fn': 'Donald Trump',
#      'nickname': 'Donald John Trump',
#      'label': 'White House',
#      'url': 'White House website'}],
# ...
